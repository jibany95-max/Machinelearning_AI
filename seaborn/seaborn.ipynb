# %%
import seaborn as sns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
iris = pd.read_csv(r"C:\Users\HP VICTUS\OneDrive\Documents\PROGRAM\ML\IRIS (1).csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
# histogram

sns.histplot(data = iris)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data = iris, x = 'petal_length', hue='species')
plt.title("Distribution of petal length")
plt.show()

# %%
sns.histplot(data = iris, x = 'petal_width', bins=20 , hue = 'species')
plt.title("Distribution of petal width")
plt.show()

# %%
sns.histplot(data = iris, x = 'sepal_length', bins=20 , hue = 'species')
plt.title("Distribution of sepal length")
plt.show()

# %%
sns.histplot(data = iris, x = 'sepal_width', bins=20 , hue = 'species')
plt.title("Distribution of sepal width")
plt.show()

# %%
# Bar plot 

sns.barplot(data= iris, x = 'species', y = 'sepal_length', palette = 'Set2')
plt.title("Bar plot of sepal length by speicies")
plt.show()
# Out:
# C:\Users\HP VICTUS\AppData\Local\Temp\ipykernel_12836\2667675173.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= iris, x = 'species', y = 'sepal_length', palette = 'Set2')

# %%
sns.barplot(data= iris, x = 'species', y = 'sepal_width', palette = 'Set2')
plt.title("Bar plot of sepal width by speicies")
plt.show()
# Out:
# C:\Users\HP VICTUS\AppData\Local\Temp\ipykernel_12836\3006109705.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= iris, x = 'species', y = 'sepal_width', palette = 'Set2')

# %%
# Bar plot 

sns.barplot(data= iris, x = 'species', y = 'petal_length', palette = 'Set2')
plt.title("Bar plot of petal length by speicies")
plt.show()
# Out:
# C:\Users\HP VICTUS\AppData\Local\Temp\ipykernel_12836\3734827396.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= iris, x = 'species', y = 'petal_length', palette = 'Set2')

# %%
# Bar plot 

sns.barplot(data= iris, x = 'species', y = 'petal_width', palette = 'Set2')
plt.title("Bar plot of petal width by speicies")
plt.show()
# Out:
# C:\Users\HP VICTUS\AppData\Local\Temp\ipykernel_12836\2769502100.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= iris, x = 'species', y = 'petal_width', palette = 'Set2')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# scatter plot

sns.scatterplot(data= iris, x = 'sepal_length', y='petal_length', hue='species')
plt.show()

# %%
sns.scatterplot(data= iris, x = 'sepal_width', y='petal_length', hue='species')
plt.show()

# %%
sns.scatterplot(data= iris, x = 'sepal_width', y='petal_width', hue='species')
plt.show()

# %%
sns.scatterplot(data= iris, x = 'sepal_length', y='petal_width', hue='species')
plt.show()

# %%
# box plot

sns.boxplot(data= iris, x= 'species', y= 'sepal_length')
plt.title("Box plot of sepal length by species")
# Out:
# Text(0.5, 1.0, 'Box plot of sepal length by species')

# %%
#heatmap
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
corr_df = iris.drop(columns='species')

# %%
corr_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.heatmap(corr_df)
# Out:
# <Axes: >

# %%
correlation = corr_df.corr()

# %%
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(data=correlation, annot= True)
plt.show()
